# %% [markdown]
# # CNN

# %% [markdown]
#  ## Importações

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import statistics as stats

import random
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
import pickle

from sklearn.model_selection import train_test_split
import sklearn

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import pandas as pd
from keras.models import model_from_json
from sklearn.metrics import confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import stats

# %% [markdown]
# ## Configurações

# %%
batch_size = 2
img_width = 128
img_height = 128
num_classes=9
image_count = 711

# %% [markdown]
# ## Importando dataset

# %%
pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

# %% [markdown]
# ## Separando Dataset

# %%
x_val = np.asarray(X[0:123])
y_val = np.asarray(y[0:123])
x_train = np.asarray(X[124:710])
y_train = np.asarray(y[124:710])

# %% [markdown]
# ## Modelo com Augumentation

# %%
data_augumentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal_and_vertical",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
      
    layers.RandomRotation(30, fill_mode='reflect',
    interpolation='bilinear',),
    layers.RandomZoom(0.2),
  ]
)

model_augumentation = Sequential([
    data_augumentation,
    layers.Conv2D(64,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(64,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dense(256, kernel_regularizer=keras.regularizers.l2(0.001), activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(64, kernel_regularizer=keras.regularizers.l2(0.001), activation='selu'),
    layers.Dropout(0.2),
    layers.Dense(num_classes, activation='softmax')
], name='augumentation_2CL')

# %% [markdown]
# ## Treinando com Augumentation

# %%
#Compilando
model_augumentation.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.metrics.SparseCategoricalAccuracy()])

#Checkpoints
checkpoint_filepath = './checkpoints/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_sparse_categorical_accuracy',
    mode='max',
    save_best_only=True)

#Treinando
epochs = 200

history_augumentation = model_augumentation.fit(x=x_train, y=y_train, validation_data=(x_val, y_val), batch_size = batch_size, epochs=epochs, callbacks=[model_checkpoint_callback])

#Carregando checkpoint
model_augumentation.load_weights(checkpoint_filepath)

model_augumentation.summary()
# Out:
# Epoch 1/200
# 293/293 [==============================] - 12s 39ms/step - loss: 2.3154 - sparse_categorical_accuracy: 0.2287 - val_loss: 14.6041 - val_sparse_categorical_accuracy: 0.1057
# Epoch 2/200
# 293/293 [==============================] - 12s 40ms/step - loss: 2.2593 - sparse_categorical_accuracy: 0.2338 - val_loss: 2.5497 - val_sparse_categorical_accuracy: 0.1789
# Epoch 3/200
# 293/293 [==============================] - 11s 38ms/step - loss: 2.2519 - sparse_categorical_accuracy: 0.2423 - val_loss: 2.0224 - val_sparse_categorical_accuracy: 0.2927
# Epoch 4/200
# 293/293 [==============================] - 8s 26ms/step - loss: 2.3050 - sparse_categorical_accuracy: 0.1655 - val_loss: 2.2513 - val_sparse_categorical_accuracy: 0.2520
# Epoch 5/200
# 293/293 [==============================] - 8s 26ms/step - loss: 2.2026 - sparse_categorical_accuracy: 0.2270 - val_loss: 2.1431 - val_sparse_categorical_accuracy: 0.2439
# Epoch 6/200
# 293/293 [==============================] - 8s 26ms/step - loss: 2.1327 - sparse_categorical_accuracy: 0.2526 - val_loss: 2.0177 - val_sparse_categorical_accuracy: 0.2927
# Epoch 7/200
# 293/293 [==============================] - 8s 27ms/step - loss: 2.2996 - sparse_categorical_accuracy: 0.2850 - val_loss: 2.2435 - val_sparse_categorical_accuracy: 0.2683
# Epoch 8/200
# 293/293 [==============================] - 8s 27ms/step - loss: 3.2653 - sparse_categorical_accuracy: 0.2765 - val_loss: 2.2978 - val_sparse_categorical_accuracy: 0.2846
# Epoch 9/200
# 293/293 [==============================] - 8s 26ms/step - loss: 2.6223 - sparse_categorical_accuracy: 0.2389 - val_loss: 2.4746 - val_sparse_categorical_accuracy: 0.2764
# Epoch 10/200
# 293/293 [==============================] - 8s 26ms/step - loss: 2.5898 - sparse_categorical_accuracy: 0.2867 - val_loss: 2.3895 - val_sparse_categorical_accuracy: 0.2602
# Epoch 11/200
# 243/293 [=======================>......] - ETA: 1s - loss: 2.5031 - sparse_categorical_accuracy: 0.3210

# %% [markdown]
# ## Carregando Modelo

# %%
#Carregando checkpoint
model_augumentation.load_weights('./checkpoints/checkpoint')

summary = model_augumentation.summary()
# Out:
# Model: "augumentation_2CL"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_6 (Sequential)   (None, 128, 128, 3)       0
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 64)      1792
#
#  spatial_dropout2d_10 (Spati  (None, 128, 128, 64)     0
#  alDropout2D)
#
#  max_pooling2d_10 (MaxPoolin  (None, 64, 64, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 32)        18464
#
#  spatial_dropout2d_11 (Spati  (None, 64, 64, 32)       0
#  alDropout2D)
#
#  max_pooling2d_11 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 32768)             0
#
#  dense_15 (Dense)            (None, 256)               8388864
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 64)                16448
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 9)                 585
#
# =================================================================
# Total params: 8,426,153
# Trainable params: 8,426,153
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Resultados com Augumentation

# %%
import statistics 

acc = history_augumentation.history['sparse_categorical_accuracy']
val_acc = history_augumentation.history['val_sparse_categorical_accuracy']

loss = history_augumentation.history['loss']
val_loss = history_augumentation.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(40, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./statistics/training_x_val.png',  dpi = 72)
plt.show()

# %% [markdown]
# ## Evaluate

# %%
print("Evaluate on test data")
results = model_augumentation.evaluate(x_val, y_val, batch_size=2)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 62/62 [==============================] - 0s 3ms/step - loss: 2.6265 - sparse_categorical_accuracy: 0.2114
# test loss, test acc: [2.6265270709991455, 0.21138212084770203]

# %% [markdown]
# ## Matriz de Confusão

# %%
predictions = model_augumentation.predict(x_val)
pred_labels = []
for predict in predictions:
    pred_labels.append(np.argmax(predict))
confusion_matrix = tf.math.confusion_matrix(y_val, pred_labels)
print(confusion_matrix)
# Out:
# tf.Tensor(
# [[ 0  0  0  1  0 11  0  0  0]
#  [ 0  0  0  1  0 11  0  0  0]
#  [ 0  0  9  0  0  6  0  0  0]
#  [ 0  0  4  0  0 16  0  0  0]
#  [ 0  0  0  0  0 13  0  0  0]
#  [ 0  0  3  0  0 17  0  0  0]
#  [ 0  0  0  0  0  8  0  0  0]
#  [ 0  0  1  0  0 10  0  0  0]
#  [ 0  0  6  0  0  6  0  0  0]], shape=(9, 9), dtype=int32)

# %% [markdown]
# ## Heatmap

# %%
y_pred_classes = np.argmax(predictions, axis=1)

y_true = y_val
errors = (y_pred_classes - y_true != 0)

labels = ['1','2','3','4','5','6','7','8','9']

y_pred_classes_errors = y_pred_classes[errors]
y_pred_errors = predictions[errors]
y_true_errors = y_true[errors]
x_test_errors = []

cm = sklearn.metrics.confusion_matrix(y_true, y_pred_classes)
thresh = cm.max() / 2,

fig, ax = plt.subplots(figsize = (12, 12))
im, cbar = stats.heatmap(cm, labels, labels, ax = ax,
cmap = plt.cm.Blues, cbarlabel = 'count of predictions')

texts = stats.annotate_heatmap(im, data = cm, threshold = thresh)

fig.tight_layout()
plt.show()
fig.savefig('statistics/heatmap.png', dpi=72)

# %% [markdown]
# ## Classification report

# %%
target_names = ['class 1', 'class 2', 'class 3','class 4', 'class 5', 'class 6','class 7', 'class 8', 'class 9']
classification_report = sklearn.metrics.classification_report(pred_labels, y_val, target_names=target_names)
# Out:
# C:\Users\intel\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\intel\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\intel\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Salvando Relatórios

# %%
arq = open("./statistics/relatorio.txt", 'w')
arq.write(f"Modelo:Augumentation 2 Camadas de Convolução\n\nEvaluate:\n{results}\n\n Matriz de Confusão:\n{confusion_matrix}\n\nClassification Report:\n{classification_report}\n\n")
arq.close()
