# %% [markdown]
# # CNN

# %% [markdown]
#  ## Importações

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import statistics as stats

import random
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
import pickle

from sklearn.model_selection import train_test_split
import sklearn

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import pandas as pd
from keras.models import model_from_json
from sklearn.metrics import confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import stats

# %% [markdown]
# ## Configurações

# %%
batch_size = 2
img_width = 128
img_height = 128
num_classes=5
image_count = 711

# %% [markdown]
# ## Importando dataset

# %%
pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

# %% [markdown]
# ## Separando Dataset

# %%
x_splitted = []
y_splitted = []

for pos, label in enumerate(y):
   if label>= 0 and label <=4:
    x_splitted.append(X[pos])
    y_splitted.append(y[pos])
    
print(len(y_splitted))

x_val = np.asarray(x_splitted[0:119])
y_val = np.asarray(y_splitted[0:119])
x_train = np.asarray(x_splitted[120:401])
y_train = np.asarray(y_splitted[120:401])
# Out:
# 402

# %% [markdown]
# ## Modelo com Augumentation

# %%
data_augumentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal_and_vertical",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
      
    layers.RandomRotation(30, fill_mode='reflect',
    interpolation='bilinear',),
    layers.RandomZoom(0.2),
  ]
)

model_augumentation = Sequential([
    data_augumentation,
    layers.Conv2D(8,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), padding='same'),
    layers.Conv2D(8,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), padding='same'),
    layers.Conv2D(16,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), padding='same'),
    layers.Conv2D(16,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), padding='same'),
    layers.Conv2D(16,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), padding='same'),
    layers.Conv2D(16,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), padding='same'),
    layers.Conv2D(16,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), padding='same'),
    layers.Conv2D(32,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), padding='same'),
    layers.Conv2D(64,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), padding='same'),
    layers.Conv2D(64,3, kernel_regularizer=keras.regularizers.l2(0.001), input_shape=(128,128,3), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), padding='same'),
    layers.Flatten(),
    layers.Dense(256, kernel_regularizer=keras.regularizers.l2(0.001), activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(64, kernel_regularizer=keras.regularizers.l2(0.001), activation='selu'),
    layers.Dropout(0.2),
    layers.Dense(num_classes, activation='softmax')
], name='augumentation_10CL')

# %% [markdown]
# ## Treinando com Augumentation

# %%
#Compilando
model_augumentation.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.metrics.SparseCategoricalAccuracy()])

#Checkpoints
checkpoint_filepath = './checkpoints/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_sparse_categorical_accuracy',
    mode='max',
    save_best_only=True)

#Treinando
epochs = 1000

history_augumentation = model_augumentation.fit(x=x_train, y=y_train, validation_data=(x_val, y_val), batch_size = batch_size, epochs=epochs, callbacks=[model_checkpoint_callback])

#Carregando checkpoint
model_augumentation.load_weights(checkpoint_filepath)

model_augumentation.summary()
# Out:
# Epoch 1/1000
# 141/141 [==============================] - 4s 16ms/step - loss: 1.6870 - sparse_categorical_accuracy: 0.2776 - val_loss: 1.4221 - val_sparse_categorical_accuracy: 0.3529
# Epoch 2/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 1.3080 - sparse_categorical_accuracy: 0.4306 - val_loss: 1.3134 - val_sparse_categorical_accuracy: 0.3950
# Epoch 3/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 1.2726 - sparse_categorical_accuracy: 0.4057 - val_loss: 1.3267 - val_sparse_categorical_accuracy: 0.3361
# Epoch 4/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 1.2600 - sparse_categorical_accuracy: 0.4093 - val_loss: 1.3598 - val_sparse_categorical_accuracy: 0.4622
# Epoch 5/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 1.1288 - sparse_categorical_accuracy: 0.4982 - val_loss: 1.3125 - val_sparse_categorical_accuracy: 0.4958
# Epoch 6/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 1.1445 - sparse_categorical_accuracy: 0.4982 - val_loss: 1.5365 - val_sparse_categorical_accuracy: 0.4538
# Epoch 7/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 1.1105 - sparse_categorical_accuracy: 0.5196 - val_loss: 1.0605 - val_sparse_categorical_accuracy: 0.5630
# Epoch 8/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 1.0832 - sparse_categorical_accuracy: 0.5374 - val_loss: 1.2656 - val_sparse_categorical_accuracy: 0.4958
# Epoch 9/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 1.0374 - sparse_categorical_accuracy: 0.5374 - val_loss: 1.3580 - val_sparse_categorical_accuracy: 0.4706
# Epoch 10/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 1.2329 - sparse_categorical_accuracy: 0.4484 - val_loss: 1.1809 - val_sparse_categorical_accuracy: 0.4370
# Epoch 11/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 1.3402 - sparse_categorical_accuracy: 0.4306 - val_loss: 1.1305 - val_sparse_categorical_accuracy: 0.5126
# Epoch 12/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 1.0863 - sparse_categorical_accuracy: 0.5338 - val_loss: 1.0671 - val_sparse_categorical_accuracy: 0.6303
# Epoch 13/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.9609 - sparse_categorical_accuracy: 0.5836 - val_loss: 1.1031 - val_sparse_categorical_accuracy: 0.5798
# Epoch 14/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.9717 - sparse_categorical_accuracy: 0.6014 - val_loss: 1.0490 - val_sparse_categorical_accuracy: 0.5546
# Epoch 15/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.9236 - sparse_categorical_accuracy: 0.5730 - val_loss: 1.0259 - val_sparse_categorical_accuracy: 0.6134
# Epoch 16/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.9351 - sparse_categorical_accuracy: 0.5872 - val_loss: 1.3129 - val_sparse_categorical_accuracy: 0.4286
# Epoch 17/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 1.0848 - sparse_categorical_accuracy: 0.5552 - val_loss: 0.9730 - val_sparse_categorical_accuracy: 0.6387
# Epoch 18/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.9336 - sparse_categorical_accuracy: 0.5836 - val_loss: 1.0400 - val_sparse_categorical_accuracy: 0.4454
# Epoch 19/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.8616 - sparse_categorical_accuracy: 0.6690 - val_loss: 0.7940 - val_sparse_categorical_accuracy: 0.7311
# Epoch 20/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8105 - sparse_categorical_accuracy: 0.6904 - val_loss: 0.8242 - val_sparse_categorical_accuracy: 0.5966
# Epoch 21/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 1.0102 - sparse_categorical_accuracy: 0.5872 - val_loss: 0.9201 - val_sparse_categorical_accuracy: 0.5966
# Epoch 22/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8366 - sparse_categorical_accuracy: 0.6584 - val_loss: 0.7121 - val_sparse_categorical_accuracy: 0.6723
# Epoch 23/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7966 - sparse_categorical_accuracy: 0.6833 - val_loss: 0.7577 - val_sparse_categorical_accuracy: 0.7479
# Epoch 24/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8495 - sparse_categorical_accuracy: 0.6619 - val_loss: 0.8160 - val_sparse_categorical_accuracy: 0.6723
# Epoch 25/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8999 - sparse_categorical_accuracy: 0.6619 - val_loss: 1.0213 - val_sparse_categorical_accuracy: 0.5798
# Epoch 26/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.9524 - sparse_categorical_accuracy: 0.6619 - val_loss: 0.8129 - val_sparse_categorical_accuracy: 0.7227
# Epoch 27/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8099 - sparse_categorical_accuracy: 0.6762 - val_loss: 0.7236 - val_sparse_categorical_accuracy: 0.6891
# Epoch 28/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6476 - sparse_categorical_accuracy: 0.7509 - val_loss: 0.8478 - val_sparse_categorical_accuracy: 0.7059
# Epoch 29/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.8051 - sparse_categorical_accuracy: 0.7224 - val_loss: 0.6942 - val_sparse_categorical_accuracy: 0.7731
# Epoch 30/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 1.1293 - sparse_categorical_accuracy: 0.5587 - val_loss: 0.8593 - val_sparse_categorical_accuracy: 0.6723
# Epoch 31/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7464 - sparse_categorical_accuracy: 0.7189 - val_loss: 0.8837 - val_sparse_categorical_accuracy: 0.6303
# Epoch 32/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7480 - sparse_categorical_accuracy: 0.7367 - val_loss: 0.7097 - val_sparse_categorical_accuracy: 0.7311
# Epoch 33/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6246 - sparse_categorical_accuracy: 0.7900 - val_loss: 0.6380 - val_sparse_categorical_accuracy: 0.7563
# Epoch 34/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.8679 - sparse_categorical_accuracy: 0.7224 - val_loss: 3.1955 - val_sparse_categorical_accuracy: 0.1597
# Epoch 35/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 1.7261 - sparse_categorical_accuracy: 0.3132 - val_loss: 1.3773 - val_sparse_categorical_accuracy: 0.4118
# Epoch 36/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 1.2959 - sparse_categorical_accuracy: 0.4484 - val_loss: 1.2347 - val_sparse_categorical_accuracy: 0.4370
# Epoch 37/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 1.0914 - sparse_categorical_accuracy: 0.5587 - val_loss: 1.0010 - val_sparse_categorical_accuracy: 0.5294
# Epoch 38/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 1.0032 - sparse_categorical_accuracy: 0.5730 - val_loss: 0.9556 - val_sparse_categorical_accuracy: 0.5630
# Epoch 39/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.9797 - sparse_categorical_accuracy: 0.5836 - val_loss: 1.1656 - val_sparse_categorical_accuracy: 0.5798
# Epoch 40/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 1.0421 - sparse_categorical_accuracy: 0.5196 - val_loss: 1.0116 - val_sparse_categorical_accuracy: 0.5798
# Epoch 41/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.9699 - sparse_categorical_accuracy: 0.5694 - val_loss: 0.9855 - val_sparse_categorical_accuracy: 0.5210
# Epoch 42/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.9445 - sparse_categorical_accuracy: 0.6370 - val_loss: 0.8452 - val_sparse_categorical_accuracy: 0.6134
# Epoch 43/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.9708 - sparse_categorical_accuracy: 0.5943 - val_loss: 0.8426 - val_sparse_categorical_accuracy: 0.6387
# Epoch 44/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.9607 - sparse_categorical_accuracy: 0.6192 - val_loss: 0.9679 - val_sparse_categorical_accuracy: 0.5546
# Epoch 45/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.8424 - sparse_categorical_accuracy: 0.6655 - val_loss: 0.9548 - val_sparse_categorical_accuracy: 0.6387
# Epoch 46/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.8285 - sparse_categorical_accuracy: 0.6762 - val_loss: 0.8181 - val_sparse_categorical_accuracy: 0.6807
# Epoch 47/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8090 - sparse_categorical_accuracy: 0.6904 - val_loss: 0.8690 - val_sparse_categorical_accuracy: 0.6555
# Epoch 48/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8477 - sparse_categorical_accuracy: 0.6263 - val_loss: 0.9356 - val_sparse_categorical_accuracy: 0.5714
# Epoch 49/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8050 - sparse_categorical_accuracy: 0.6833 - val_loss: 0.8770 - val_sparse_categorical_accuracy: 0.5966
# Epoch 50/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8827 - sparse_categorical_accuracy: 0.6548 - val_loss: 1.0477 - val_sparse_categorical_accuracy: 0.5126
# Epoch 51/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8527 - sparse_categorical_accuracy: 0.6584 - val_loss: 0.7746 - val_sparse_categorical_accuracy: 0.6639
# Epoch 52/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.7438 - sparse_categorical_accuracy: 0.6762 - val_loss: 0.8273 - val_sparse_categorical_accuracy: 0.6218
# Epoch 53/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8903 - sparse_categorical_accuracy: 0.6441 - val_loss: 1.9503 - val_sparse_categorical_accuracy: 0.3193
# Epoch 54/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7870 - sparse_categorical_accuracy: 0.6833 - val_loss: 0.8347 - val_sparse_categorical_accuracy: 0.6134
# Epoch 55/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7382 - sparse_categorical_accuracy: 0.7331 - val_loss: 0.7821 - val_sparse_categorical_accuracy: 0.6471
# Epoch 56/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7691 - sparse_categorical_accuracy: 0.6868 - val_loss: 1.2638 - val_sparse_categorical_accuracy: 0.5294
# Epoch 57/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8293 - sparse_categorical_accuracy: 0.6655 - val_loss: 0.9053 - val_sparse_categorical_accuracy: 0.5630
# Epoch 58/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6820 - sparse_categorical_accuracy: 0.7260 - val_loss: 0.9440 - val_sparse_categorical_accuracy: 0.5546
# Epoch 59/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7144 - sparse_categorical_accuracy: 0.7189 - val_loss: 0.9587 - val_sparse_categorical_accuracy: 0.5546
# Epoch 60/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6881 - sparse_categorical_accuracy: 0.7189 - val_loss: 0.7026 - val_sparse_categorical_accuracy: 0.7227
# Epoch 61/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7340 - sparse_categorical_accuracy: 0.6975 - val_loss: 0.7311 - val_sparse_categorical_accuracy: 0.6639
# Epoch 62/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7439 - sparse_categorical_accuracy: 0.7082 - val_loss: 0.8390 - val_sparse_categorical_accuracy: 0.6050
# Epoch 63/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6351 - sparse_categorical_accuracy: 0.7509 - val_loss: 0.6512 - val_sparse_categorical_accuracy: 0.6891
# Epoch 64/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7550 - sparse_categorical_accuracy: 0.7046 - val_loss: 1.0374 - val_sparse_categorical_accuracy: 0.5210
# Epoch 65/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6998 - sparse_categorical_accuracy: 0.7153 - val_loss: 0.7965 - val_sparse_categorical_accuracy: 0.5966
# Epoch 66/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6531 - sparse_categorical_accuracy: 0.7367 - val_loss: 0.9913 - val_sparse_categorical_accuracy: 0.5462
# Epoch 67/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7311 - sparse_categorical_accuracy: 0.7046 - val_loss: 0.8209 - val_sparse_categorical_accuracy: 0.5966
# Epoch 68/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 1.1539 - sparse_categorical_accuracy: 0.6085 - val_loss: 1.9130 - val_sparse_categorical_accuracy: 0.2269
# Epoch 69/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 1.4169 - sparse_categorical_accuracy: 0.3523 - val_loss: 0.8924 - val_sparse_categorical_accuracy: 0.5630
# Epoch 70/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.7073 - sparse_categorical_accuracy: 0.7473 - val_loss: 0.7054 - val_sparse_categorical_accuracy: 0.6807
# Epoch 71/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6425 - sparse_categorical_accuracy: 0.7616 - val_loss: 0.7386 - val_sparse_categorical_accuracy: 0.6471
# Epoch 72/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6193 - sparse_categorical_accuracy: 0.7580 - val_loss: 0.8439 - val_sparse_categorical_accuracy: 0.5966
# Epoch 73/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6833 - sparse_categorical_accuracy: 0.7082 - val_loss: 0.6790 - val_sparse_categorical_accuracy: 0.6891
# Epoch 74/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6960 - sparse_categorical_accuracy: 0.7367 - val_loss: 0.6613 - val_sparse_categorical_accuracy: 0.6639
# Epoch 75/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6402 - sparse_categorical_accuracy: 0.7367 - val_loss: 0.6332 - val_sparse_categorical_accuracy: 0.6807
# Epoch 76/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6184 - sparse_categorical_accuracy: 0.7580 - val_loss: 0.7296 - val_sparse_categorical_accuracy: 0.6807
# Epoch 77/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6443 - sparse_categorical_accuracy: 0.7544 - val_loss: 0.5813 - val_sparse_categorical_accuracy: 0.7143
# Epoch 78/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.9444 - sparse_categorical_accuracy: 0.6833 - val_loss: 0.6549 - val_sparse_categorical_accuracy: 0.7059
# Epoch 79/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5907 - sparse_categorical_accuracy: 0.7616 - val_loss: 0.7084 - val_sparse_categorical_accuracy: 0.6555
# Epoch 80/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5918 - sparse_categorical_accuracy: 0.7438 - val_loss: 0.6258 - val_sparse_categorical_accuracy: 0.6555
# Epoch 81/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5842 - sparse_categorical_accuracy: 0.7580 - val_loss: 0.6861 - val_sparse_categorical_accuracy: 0.6807
# Epoch 82/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.6349 - sparse_categorical_accuracy: 0.7580 - val_loss: 0.7370 - val_sparse_categorical_accuracy: 0.6134
# Epoch 83/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5968 - sparse_categorical_accuracy: 0.7544 - val_loss: 0.6440 - val_sparse_categorical_accuracy: 0.6891
# Epoch 84/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5233 - sparse_categorical_accuracy: 0.8078 - val_loss: 0.8279 - val_sparse_categorical_accuracy: 0.6050
# Epoch 85/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.6714 - sparse_categorical_accuracy: 0.7331 - val_loss: 0.5722 - val_sparse_categorical_accuracy: 0.6807
# Epoch 86/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5677 - sparse_categorical_accuracy: 0.7544 - val_loss: 0.6100 - val_sparse_categorical_accuracy: 0.6807
# Epoch 87/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.6618 - sparse_categorical_accuracy: 0.7367 - val_loss: 0.5908 - val_sparse_categorical_accuracy: 0.7059
# Epoch 88/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.6886 - sparse_categorical_accuracy: 0.7367 - val_loss: 0.7177 - val_sparse_categorical_accuracy: 0.6387
# Epoch 89/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5655 - sparse_categorical_accuracy: 0.7794 - val_loss: 0.5495 - val_sparse_categorical_accuracy: 0.7059
# Epoch 90/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.5427 - sparse_categorical_accuracy: 0.7580 - val_loss: 0.6119 - val_sparse_categorical_accuracy: 0.6639
# Epoch 91/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6190 - sparse_categorical_accuracy: 0.7616 - val_loss: 0.5497 - val_sparse_categorical_accuracy: 0.6891
# Epoch 92/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5660 - sparse_categorical_accuracy: 0.7722 - val_loss: 0.6887 - val_sparse_categorical_accuracy: 0.6639
# Epoch 93/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.5097 - sparse_categorical_accuracy: 0.7900 - val_loss: 0.6307 - val_sparse_categorical_accuracy: 0.6723
# Epoch 94/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5848 - sparse_categorical_accuracy: 0.7580 - val_loss: 0.4995 - val_sparse_categorical_accuracy: 0.6975
# Epoch 95/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4740 - sparse_categorical_accuracy: 0.8043 - val_loss: 0.5901 - val_sparse_categorical_accuracy: 0.6891
# Epoch 96/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5160 - sparse_categorical_accuracy: 0.7972 - val_loss: 0.5042 - val_sparse_categorical_accuracy: 0.7143
# Epoch 97/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5479 - sparse_categorical_accuracy: 0.7687 - val_loss: 0.6617 - val_sparse_categorical_accuracy: 0.6471
# Epoch 98/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.8151 - sparse_categorical_accuracy: 0.7260 - val_loss: 0.6424 - val_sparse_categorical_accuracy: 0.6639
# Epoch 99/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5090 - sparse_categorical_accuracy: 0.7829 - val_loss: 0.5212 - val_sparse_categorical_accuracy: 0.7227
# Epoch 100/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5223 - sparse_categorical_accuracy: 0.7936 - val_loss: 0.5064 - val_sparse_categorical_accuracy: 0.7311
# Epoch 101/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5054 - sparse_categorical_accuracy: 0.8221 - val_loss: 0.4657 - val_sparse_categorical_accuracy: 0.7395
# Epoch 102/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4987 - sparse_categorical_accuracy: 0.7758 - val_loss: 0.4501 - val_sparse_categorical_accuracy: 0.7647
# Epoch 103/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4756 - sparse_categorical_accuracy: 0.7794 - val_loss: 0.4546 - val_sparse_categorical_accuracy: 0.7563
# Epoch 104/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5073 - sparse_categorical_accuracy: 0.7758 - val_loss: 0.4622 - val_sparse_categorical_accuracy: 0.7647
# Epoch 105/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4512 - sparse_categorical_accuracy: 0.8363 - val_loss: 0.4698 - val_sparse_categorical_accuracy: 0.7647
# Epoch 106/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5622 - sparse_categorical_accuracy: 0.7509 - val_loss: 0.5155 - val_sparse_categorical_accuracy: 0.7563
# Epoch 107/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.3870 - sparse_categorical_accuracy: 0.8292 - val_loss: 0.4792 - val_sparse_categorical_accuracy: 0.7731
# Epoch 108/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.6027 - sparse_categorical_accuracy: 0.7936 - val_loss: 0.5330 - val_sparse_categorical_accuracy: 0.7899
# Epoch 109/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4407 - sparse_categorical_accuracy: 0.8256 - val_loss: 0.4361 - val_sparse_categorical_accuracy: 0.8655
# Epoch 110/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4751 - sparse_categorical_accuracy: 0.8149 - val_loss: 0.6687 - val_sparse_categorical_accuracy: 0.6555
# Epoch 111/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5344 - sparse_categorical_accuracy: 0.7972 - val_loss: 0.4943 - val_sparse_categorical_accuracy: 0.7479
# Epoch 112/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4973 - sparse_categorical_accuracy: 0.7900 - val_loss: 0.5226 - val_sparse_categorical_accuracy: 0.7311
# Epoch 113/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4978 - sparse_categorical_accuracy: 0.7900 - val_loss: 0.5712 - val_sparse_categorical_accuracy: 0.7395
# Epoch 114/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4454 - sparse_categorical_accuracy: 0.8043 - val_loss: 0.5940 - val_sparse_categorical_accuracy: 0.7563
# Epoch 115/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4997 - sparse_categorical_accuracy: 0.8007 - val_loss: 0.8186 - val_sparse_categorical_accuracy: 0.6555
# Epoch 116/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5242 - sparse_categorical_accuracy: 0.8292 - val_loss: 0.4851 - val_sparse_categorical_accuracy: 0.7647
# Epoch 117/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3774 - sparse_categorical_accuracy: 0.8399 - val_loss: 0.6294 - val_sparse_categorical_accuracy: 0.6723
# Epoch 118/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4089 - sparse_categorical_accuracy: 0.8470 - val_loss: 0.5148 - val_sparse_categorical_accuracy: 0.7647
# Epoch 119/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4869 - sparse_categorical_accuracy: 0.8292 - val_loss: 0.3801 - val_sparse_categorical_accuracy: 0.8487
# Epoch 120/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4286 - sparse_categorical_accuracy: 0.8541 - val_loss: 0.3951 - val_sparse_categorical_accuracy: 0.8571
# Epoch 121/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4970 - sparse_categorical_accuracy: 0.8007 - val_loss: 1.0931 - val_sparse_categorical_accuracy: 0.6134
# Epoch 122/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4653 - sparse_categorical_accuracy: 0.7936 - val_loss: 0.6112 - val_sparse_categorical_accuracy: 0.7059
# Epoch 123/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4708 - sparse_categorical_accuracy: 0.8185 - val_loss: 0.4571 - val_sparse_categorical_accuracy: 0.8151
# Epoch 124/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4826 - sparse_categorical_accuracy: 0.8256 - val_loss: 0.4672 - val_sparse_categorical_accuracy: 0.7983
# Epoch 125/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4461 - sparse_categorical_accuracy: 0.8470 - val_loss: 0.5131 - val_sparse_categorical_accuracy: 0.7563
# Epoch 126/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4255 - sparse_categorical_accuracy: 0.8399 - val_loss: 0.5047 - val_sparse_categorical_accuracy: 0.7815
# Epoch 127/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4924 - sparse_categorical_accuracy: 0.8185 - val_loss: 0.4662 - val_sparse_categorical_accuracy: 0.8067
# Epoch 128/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4084 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.3911 - val_sparse_categorical_accuracy: 0.8487
# Epoch 129/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3501 - sparse_categorical_accuracy: 0.8932 - val_loss: 0.4676 - val_sparse_categorical_accuracy: 0.7983
# Epoch 130/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5022 - sparse_categorical_accuracy: 0.8149 - val_loss: 0.4121 - val_sparse_categorical_accuracy: 0.8487
# Epoch 131/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4250 - sparse_categorical_accuracy: 0.8327 - val_loss: 0.4281 - val_sparse_categorical_accuracy: 0.8235
# Epoch 132/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6538 - sparse_categorical_accuracy: 0.7758 - val_loss: 0.4901 - val_sparse_categorical_accuracy: 0.7563
# Epoch 133/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.5724 - sparse_categorical_accuracy: 0.7722 - val_loss: 1.3114 - val_sparse_categorical_accuracy: 0.6218
# Epoch 134/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4381 - sparse_categorical_accuracy: 0.8399 - val_loss: 0.4463 - val_sparse_categorical_accuracy: 0.8067
# Epoch 135/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.5273 - sparse_categorical_accuracy: 0.8114 - val_loss: 0.4413 - val_sparse_categorical_accuracy: 0.8403
# Epoch 136/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5616 - sparse_categorical_accuracy: 0.8221 - val_loss: 0.5066 - val_sparse_categorical_accuracy: 0.7563
# Epoch 137/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4411 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.5713 - val_sparse_categorical_accuracy: 0.7059
# Epoch 138/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4044 - sparse_categorical_accuracy: 0.8505 - val_loss: 0.4228 - val_sparse_categorical_accuracy: 0.8151
# Epoch 139/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4670 - sparse_categorical_accuracy: 0.8221 - val_loss: 0.3874 - val_sparse_categorical_accuracy: 0.8571
# Epoch 140/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4027 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.5492 - val_sparse_categorical_accuracy: 0.7395
# Epoch 141/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4121 - sparse_categorical_accuracy: 0.8577 - val_loss: 0.4438 - val_sparse_categorical_accuracy: 0.8151
# Epoch 142/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3901 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.8114 - val_sparse_categorical_accuracy: 0.6975
# Epoch 143/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4256 - sparse_categorical_accuracy: 0.8185 - val_loss: 0.4706 - val_sparse_categorical_accuracy: 0.8403
# Epoch 144/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.4562 - sparse_categorical_accuracy: 0.8114 - val_loss: 0.4429 - val_sparse_categorical_accuracy: 0.8067
# Epoch 145/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4035 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.3764 - val_sparse_categorical_accuracy: 0.8739
# Epoch 146/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4488 - sparse_categorical_accuracy: 0.8221 - val_loss: 0.5429 - val_sparse_categorical_accuracy: 0.7647
# Epoch 147/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4056 - sparse_categorical_accuracy: 0.8541 - val_loss: 0.6174 - val_sparse_categorical_accuracy: 0.7395
# Epoch 148/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3856 - sparse_categorical_accuracy: 0.8612 - val_loss: 1.4072 - val_sparse_categorical_accuracy: 0.6807
# Epoch 149/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5666 - sparse_categorical_accuracy: 0.7900 - val_loss: 0.4248 - val_sparse_categorical_accuracy: 0.8403
# Epoch 150/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.3807 - sparse_categorical_accuracy: 0.8683 - val_loss: 0.3935 - val_sparse_categorical_accuracy: 0.8487
# Epoch 151/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4833 - sparse_categorical_accuracy: 0.8043 - val_loss: 0.4383 - val_sparse_categorical_accuracy: 0.8151
# Epoch 152/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4995 - sparse_categorical_accuracy: 0.8114 - val_loss: 0.5273 - val_sparse_categorical_accuracy: 0.7563
# Epoch 153/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5024 - sparse_categorical_accuracy: 0.8363 - val_loss: 0.4448 - val_sparse_categorical_accuracy: 0.8067
# Epoch 154/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4307 - sparse_categorical_accuracy: 0.8292 - val_loss: 1.1783 - val_sparse_categorical_accuracy: 0.6891
# Epoch 155/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4686 - sparse_categorical_accuracy: 0.8114 - val_loss: 0.5320 - val_sparse_categorical_accuracy: 0.7647
# Epoch 156/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3522 - sparse_categorical_accuracy: 0.8754 - val_loss: 0.5415 - val_sparse_categorical_accuracy: 0.7479
# Epoch 157/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4249 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.3969 - val_sparse_categorical_accuracy: 0.8403
# Epoch 158/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4428 - sparse_categorical_accuracy: 0.8221 - val_loss: 0.4175 - val_sparse_categorical_accuracy: 0.8235
# Epoch 159/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4236 - sparse_categorical_accuracy: 0.8648 - val_loss: 0.4608 - val_sparse_categorical_accuracy: 0.8151
# Epoch 160/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.6793 - sparse_categorical_accuracy: 0.7936 - val_loss: 0.4517 - val_sparse_categorical_accuracy: 0.8151
# Epoch 161/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3688 - sparse_categorical_accuracy: 0.8719 - val_loss: 0.4077 - val_sparse_categorical_accuracy: 0.8571
# Epoch 162/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4409 - sparse_categorical_accuracy: 0.8363 - val_loss: 0.5771 - val_sparse_categorical_accuracy: 0.7395
# Epoch 163/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4198 - sparse_categorical_accuracy: 0.8078 - val_loss: 0.4676 - val_sparse_categorical_accuracy: 0.7731
# Epoch 164/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4626 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.3876 - val_sparse_categorical_accuracy: 0.8403
# Epoch 165/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3955 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.4097 - val_sparse_categorical_accuracy: 0.8487
# Epoch 166/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4246 - sparse_categorical_accuracy: 0.8577 - val_loss: 0.5158 - val_sparse_categorical_accuracy: 0.7815
# Epoch 167/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4232 - sparse_categorical_accuracy: 0.8363 - val_loss: 0.3370 - val_sparse_categorical_accuracy: 0.8824
# Epoch 168/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3717 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.4139 - val_sparse_categorical_accuracy: 0.8487
# Epoch 169/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3957 - sparse_categorical_accuracy: 0.8683 - val_loss: 0.3401 - val_sparse_categorical_accuracy: 0.8739
# Epoch 170/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4655 - sparse_categorical_accuracy: 0.8327 - val_loss: 0.5638 - val_sparse_categorical_accuracy: 0.7815
# Epoch 171/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5046 - sparse_categorical_accuracy: 0.8007 - val_loss: 0.6112 - val_sparse_categorical_accuracy: 0.7143
# Epoch 172/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3710 - sparse_categorical_accuracy: 0.8648 - val_loss: 0.3444 - val_sparse_categorical_accuracy: 0.8235
# Epoch 173/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3571 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.3503 - val_sparse_categorical_accuracy: 0.8739
# Epoch 174/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4254 - sparse_categorical_accuracy: 0.8149 - val_loss: 0.4049 - val_sparse_categorical_accuracy: 0.8824
# Epoch 175/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4100 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.4746 - val_sparse_categorical_accuracy: 0.8403
# Epoch 176/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3777 - sparse_categorical_accuracy: 0.8719 - val_loss: 0.3267 - val_sparse_categorical_accuracy: 0.8655
# Epoch 177/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4017 - sparse_categorical_accuracy: 0.8719 - val_loss: 0.8246 - val_sparse_categorical_accuracy: 0.7983
# Epoch 178/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3795 - sparse_categorical_accuracy: 0.8541 - val_loss: 0.5222 - val_sparse_categorical_accuracy: 0.7899
# Epoch 179/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3973 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.3521 - val_sparse_categorical_accuracy: 0.8319
# Epoch 180/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3516 - sparse_categorical_accuracy: 0.8719 - val_loss: 0.7416 - val_sparse_categorical_accuracy: 0.6807
# Epoch 181/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3729 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.6358 - val_sparse_categorical_accuracy: 0.7647
# Epoch 182/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3923 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.4291 - val_sparse_categorical_accuracy: 0.7815
# Epoch 183/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3258 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.5720 - val_sparse_categorical_accuracy: 0.8235
# Epoch 184/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3948 - sparse_categorical_accuracy: 0.8327 - val_loss: 0.4358 - val_sparse_categorical_accuracy: 0.8319
# Epoch 185/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5828 - sparse_categorical_accuracy: 0.8043 - val_loss: 0.8434 - val_sparse_categorical_accuracy: 0.6050
# Epoch 186/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5037 - sparse_categorical_accuracy: 0.8327 - val_loss: 0.3444 - val_sparse_categorical_accuracy: 0.8571
# Epoch 187/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3372 - sparse_categorical_accuracy: 0.8968 - val_loss: 0.4753 - val_sparse_categorical_accuracy: 0.7899
# Epoch 188/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3807 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.5086 - val_sparse_categorical_accuracy: 0.7563
# Epoch 189/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4164 - sparse_categorical_accuracy: 0.8399 - val_loss: 0.4537 - val_sparse_categorical_accuracy: 0.8235
# Epoch 190/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3782 - sparse_categorical_accuracy: 0.8541 - val_loss: 0.3656 - val_sparse_categorical_accuracy: 0.8908
# Epoch 191/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3763 - sparse_categorical_accuracy: 0.8648 - val_loss: 0.4367 - val_sparse_categorical_accuracy: 0.8487
# Epoch 192/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2686 - sparse_categorical_accuracy: 0.9110 - val_loss: 0.3387 - val_sparse_categorical_accuracy: 0.8655
# Epoch 193/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3035 - sparse_categorical_accuracy: 0.9039 - val_loss: 0.3074 - val_sparse_categorical_accuracy: 0.8739
# Epoch 194/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4049 - sparse_categorical_accuracy: 0.8577 - val_loss: 0.3412 - val_sparse_categorical_accuracy: 0.8571
# Epoch 195/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3783 - sparse_categorical_accuracy: 0.9039 - val_loss: 0.7620 - val_sparse_categorical_accuracy: 0.7647
# Epoch 196/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3323 - sparse_categorical_accuracy: 0.8932 - val_loss: 0.3236 - val_sparse_categorical_accuracy: 0.9160
# Epoch 197/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3334 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.3244 - val_sparse_categorical_accuracy: 0.8908
# Epoch 198/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.4079 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.3994 - val_sparse_categorical_accuracy: 0.8824
# Epoch 199/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.4299 - sparse_categorical_accuracy: 0.8505 - val_loss: 0.4110 - val_sparse_categorical_accuracy: 0.8319
# Epoch 200/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3114 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.3140 - val_sparse_categorical_accuracy: 0.8824
# Epoch 201/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3588 - sparse_categorical_accuracy: 0.8897 - val_loss: 0.3528 - val_sparse_categorical_accuracy: 0.8992
# Epoch 202/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3016 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.3407 - val_sparse_categorical_accuracy: 0.8655
# Epoch 203/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3341 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.3882 - val_sparse_categorical_accuracy: 0.8571
# Epoch 204/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3160 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.4268 - val_sparse_categorical_accuracy: 0.8487
# Epoch 205/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4378 - sparse_categorical_accuracy: 0.8683 - val_loss: 0.3811 - val_sparse_categorical_accuracy: 0.8655
# Epoch 206/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.4842 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.3447 - val_sparse_categorical_accuracy: 0.8571
# Epoch 207/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3848 - sparse_categorical_accuracy: 0.8577 - val_loss: 0.4814 - val_sparse_categorical_accuracy: 0.7731
# Epoch 208/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3190 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.3149 - val_sparse_categorical_accuracy: 0.8824
# Epoch 209/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.3905 - sparse_categorical_accuracy: 0.8577 - val_loss: 0.3506 - val_sparse_categorical_accuracy: 0.8571
# Epoch 210/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3539 - sparse_categorical_accuracy: 0.9004 - val_loss: 0.3839 - val_sparse_categorical_accuracy: 0.8403
# Epoch 211/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5977 - sparse_categorical_accuracy: 0.8149 - val_loss: 0.4124 - val_sparse_categorical_accuracy: 0.8571
# Epoch 212/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3337 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.2970 - val_sparse_categorical_accuracy: 0.8992
# Epoch 213/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3191 - sparse_categorical_accuracy: 0.8897 - val_loss: 0.3820 - val_sparse_categorical_accuracy: 0.8571
# Epoch 214/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.4022 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.3299 - val_sparse_categorical_accuracy: 0.8824
# Epoch 215/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3750 - sparse_categorical_accuracy: 0.8648 - val_loss: 0.3125 - val_sparse_categorical_accuracy: 0.8992
# Epoch 216/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3102 - sparse_categorical_accuracy: 0.9075 - val_loss: 0.3217 - val_sparse_categorical_accuracy: 0.9160
# Epoch 217/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3257 - sparse_categorical_accuracy: 0.9004 - val_loss: 0.3160 - val_sparse_categorical_accuracy: 0.9076
# Epoch 218/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3426 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.3917 - val_sparse_categorical_accuracy: 0.8992
# Epoch 219/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3585 - sparse_categorical_accuracy: 0.8577 - val_loss: 0.3622 - val_sparse_categorical_accuracy: 0.8824
# Epoch 220/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3055 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.3900 - val_sparse_categorical_accuracy: 0.8487
# Epoch 221/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.2953 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.4928 - val_sparse_categorical_accuracy: 0.8319
# Epoch 222/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.4118 - sparse_categorical_accuracy: 0.8541 - val_loss: 0.4991 - val_sparse_categorical_accuracy: 0.7983
# Epoch 223/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3379 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.3044 - val_sparse_categorical_accuracy: 0.9076
# Epoch 224/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3185 - sparse_categorical_accuracy: 0.8754 - val_loss: 0.4273 - val_sparse_categorical_accuracy: 0.8824
# Epoch 225/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5365 - sparse_categorical_accuracy: 0.8327 - val_loss: 0.3730 - val_sparse_categorical_accuracy: 0.8908
# Epoch 226/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3578 - sparse_categorical_accuracy: 0.8541 - val_loss: 0.3196 - val_sparse_categorical_accuracy: 0.8908
# Epoch 227/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3261 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.3736 - val_sparse_categorical_accuracy: 0.8824
# Epoch 228/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3588 - sparse_categorical_accuracy: 0.8719 - val_loss: 0.3960 - val_sparse_categorical_accuracy: 0.8403
# Epoch 229/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3271 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.3136 - val_sparse_categorical_accuracy: 0.8992
# Epoch 230/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3753 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.3859 - val_sparse_categorical_accuracy: 0.8235
# Epoch 231/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3184 - sparse_categorical_accuracy: 0.8968 - val_loss: 0.3547 - val_sparse_categorical_accuracy: 0.8908
# Epoch 232/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3115 - sparse_categorical_accuracy: 0.8932 - val_loss: 0.5104 - val_sparse_categorical_accuracy: 0.8067
# Epoch 233/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.4063 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.3455 - val_sparse_categorical_accuracy: 0.8739
# Epoch 234/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3009 - sparse_categorical_accuracy: 0.9075 - val_loss: 0.3809 - val_sparse_categorical_accuracy: 0.8655
# Epoch 235/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.3478 - sparse_categorical_accuracy: 0.8897 - val_loss: 0.3501 - val_sparse_categorical_accuracy: 0.8739
# Epoch 236/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3597 - sparse_categorical_accuracy: 0.8719 - val_loss: 0.3206 - val_sparse_categorical_accuracy: 0.8908
# Epoch 237/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 1.4736 - sparse_categorical_accuracy: 0.5267 - val_loss: 1.2801 - val_sparse_categorical_accuracy: 0.4538
# Epoch 238/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 1.2642 - sparse_categorical_accuracy: 0.4875 - val_loss: 1.3268 - val_sparse_categorical_accuracy: 0.3697
# Epoch 239/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 1.0714 - sparse_categorical_accuracy: 0.5801 - val_loss: 1.7303 - val_sparse_categorical_accuracy: 0.2773
# Epoch 240/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 1.1361 - sparse_categorical_accuracy: 0.5552 - val_loss: 0.9233 - val_sparse_categorical_accuracy: 0.5630
# Epoch 241/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.9567 - sparse_categorical_accuracy: 0.6085 - val_loss: 0.8163 - val_sparse_categorical_accuracy: 0.6218
# Epoch 242/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.7686 - sparse_categorical_accuracy: 0.7117 - val_loss: 0.7926 - val_sparse_categorical_accuracy: 0.6807
# Epoch 243/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.7822 - sparse_categorical_accuracy: 0.6904 - val_loss: 0.8638 - val_sparse_categorical_accuracy: 0.5630
# Epoch 244/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.7587 - sparse_categorical_accuracy: 0.7117 - val_loss: 1.1115 - val_sparse_categorical_accuracy: 0.5882
# Epoch 245/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.7211 - sparse_categorical_accuracy: 0.7117 - val_loss: 0.8688 - val_sparse_categorical_accuracy: 0.7059
# Epoch 246/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.6911 - sparse_categorical_accuracy: 0.7367 - val_loss: 0.6567 - val_sparse_categorical_accuracy: 0.7563
# Epoch 247/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.6602 - sparse_categorical_accuracy: 0.7438 - val_loss: 0.5793 - val_sparse_categorical_accuracy: 0.8235
# Epoch 248/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.6848 - sparse_categorical_accuracy: 0.7438 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.7479
# Epoch 249/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.6269 - sparse_categorical_accuracy: 0.7865 - val_loss: 0.7078 - val_sparse_categorical_accuracy: 0.7143
# Epoch 250/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.6205 - sparse_categorical_accuracy: 0.7794 - val_loss: 0.5415 - val_sparse_categorical_accuracy: 0.8319
# Epoch 251/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.6257 - sparse_categorical_accuracy: 0.7972 - val_loss: 0.5643 - val_sparse_categorical_accuracy: 0.8235
# Epoch 252/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5473 - sparse_categorical_accuracy: 0.8221 - val_loss: 0.9078 - val_sparse_categorical_accuracy: 0.6387
# Epoch 253/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.5504 - sparse_categorical_accuracy: 0.8007 - val_loss: 0.5665 - val_sparse_categorical_accuracy: 0.7983
# Epoch 254/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.5810 - sparse_categorical_accuracy: 0.8256 - val_loss: 0.6294 - val_sparse_categorical_accuracy: 0.7311
# Epoch 255/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.5395 - sparse_categorical_accuracy: 0.8078 - val_loss: 0.6259 - val_sparse_categorical_accuracy: 0.7311
# Epoch 256/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.5717 - sparse_categorical_accuracy: 0.7936 - val_loss: 0.5914 - val_sparse_categorical_accuracy: 0.7059
# Epoch 257/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.5332 - sparse_categorical_accuracy: 0.7829 - val_loss: 0.6078 - val_sparse_categorical_accuracy: 0.7059
# Epoch 258/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.5224 - sparse_categorical_accuracy: 0.7972 - val_loss: 0.5814 - val_sparse_categorical_accuracy: 0.7815
# Epoch 259/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.5440 - sparse_categorical_accuracy: 0.7865 - val_loss: 0.6381 - val_sparse_categorical_accuracy: 0.6723
# Epoch 260/1000
# 141/141 [==============================] - 2s 13ms/step - loss: 0.5239 - sparse_categorical_accuracy: 0.8114 - val_loss: 0.6078 - val_sparse_categorical_accuracy: 0.7479
# ...
# Epoch 939/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2272 - sparse_categorical_accuracy: 0.9502 - val_loss: 0.4863 - val_sparse_categorical_accuracy: 0.8571
# Epoch 940/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2823 - sparse_categorical_accuracy: 0.9288 - val_loss: 0.3793 - val_sparse_categorical_accuracy: 0.8739
# Epoch 941/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2185 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.3987 - val_sparse_categorical_accuracy: 0.8992
# Epoch 942/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2070 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.4190 - val_sparse_categorical_accuracy: 0.8739
# Epoch 943/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2161 - sparse_categorical_accuracy: 0.9537 - val_loss: 0.3118 - val_sparse_categorical_accuracy: 0.9244
# Epoch 944/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2320 - sparse_categorical_accuracy: 0.9502 - val_loss: 0.2833 - val_sparse_categorical_accuracy: 0.9412
# Epoch 945/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2137 - sparse_categorical_accuracy: 0.9502 - val_loss: 0.3006 - val_sparse_categorical_accuracy: 0.9328
# Epoch 946/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2105 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.4322 - val_sparse_categorical_accuracy: 0.8908
# Epoch 947/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1610 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.3343 - val_sparse_categorical_accuracy: 0.9328
# Epoch 948/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2801 - sparse_categorical_accuracy: 0.9253 - val_loss: 0.3681 - val_sparse_categorical_accuracy: 0.8992
# Epoch 949/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2499 - sparse_categorical_accuracy: 0.9466 - val_loss: 0.2976 - val_sparse_categorical_accuracy: 0.9412
# Epoch 950/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1877 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.2675 - val_sparse_categorical_accuracy: 0.9412
# Epoch 951/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1749 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.2928 - val_sparse_categorical_accuracy: 0.9328
# Epoch 952/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1621 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.2875 - val_sparse_categorical_accuracy: 0.9328
# Epoch 953/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2370 - sparse_categorical_accuracy: 0.9395 - val_loss: 0.2981 - val_sparse_categorical_accuracy: 0.9412
# Epoch 954/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.3288 - sparse_categorical_accuracy: 0.9075 - val_loss: 0.4421 - val_sparse_categorical_accuracy: 0.8824
# Epoch 955/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2214 - sparse_categorical_accuracy: 0.9324 - val_loss: 0.4018 - val_sparse_categorical_accuracy: 0.8908
# Epoch 956/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1900 - sparse_categorical_accuracy: 0.9537 - val_loss: 0.4181 - val_sparse_categorical_accuracy: 0.8908
# Epoch 957/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2069 - sparse_categorical_accuracy: 0.9395 - val_loss: 0.3964 - val_sparse_categorical_accuracy: 0.8908
# Epoch 958/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2081 - sparse_categorical_accuracy: 0.9502 - val_loss: 0.3287 - val_sparse_categorical_accuracy: 0.8992
# Epoch 959/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2328 - sparse_categorical_accuracy: 0.9288 - val_loss: 0.2541 - val_sparse_categorical_accuracy: 0.9328
# Epoch 960/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2561 - sparse_categorical_accuracy: 0.9324 - val_loss: 0.3128 - val_sparse_categorical_accuracy: 0.9160
# Epoch 961/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2657 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.2598 - val_sparse_categorical_accuracy: 0.9496
# Epoch 962/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1570 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.3312 - val_sparse_categorical_accuracy: 0.9328
# Epoch 963/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1631 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.2904 - val_sparse_categorical_accuracy: 0.9496
# Epoch 964/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2417 - sparse_categorical_accuracy: 0.9288 - val_loss: 0.5363 - val_sparse_categorical_accuracy: 0.8403
# Epoch 965/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2147 - sparse_categorical_accuracy: 0.9466 - val_loss: 0.3462 - val_sparse_categorical_accuracy: 0.9328
# Epoch 966/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2696 - sparse_categorical_accuracy: 0.9288 - val_loss: 0.2830 - val_sparse_categorical_accuracy: 0.9328
# Epoch 967/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2958 - sparse_categorical_accuracy: 0.9466 - val_loss: 0.2706 - val_sparse_categorical_accuracy: 0.9244
# Epoch 968/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1759 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.4151 - val_sparse_categorical_accuracy: 0.8992
# Epoch 969/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1662 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.4982 - val_sparse_categorical_accuracy: 0.8655
# Epoch 970/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1851 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.3043 - val_sparse_categorical_accuracy: 0.9244
# Epoch 971/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2608 - sparse_categorical_accuracy: 0.9253 - val_loss: 0.3136 - val_sparse_categorical_accuracy: 0.9328
# Epoch 972/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2704 - sparse_categorical_accuracy: 0.9253 - val_loss: 0.6140 - val_sparse_categorical_accuracy: 0.8403
# Epoch 973/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1609 - sparse_categorical_accuracy: 0.9680 - val_loss: 0.2498 - val_sparse_categorical_accuracy: 0.9412
# Epoch 974/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1921 - sparse_categorical_accuracy: 0.9537 - val_loss: 0.4973 - val_sparse_categorical_accuracy: 0.8824
# Epoch 975/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1969 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.2291 - val_sparse_categorical_accuracy: 0.9580
# Epoch 976/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2000 - sparse_categorical_accuracy: 0.9466 - val_loss: 0.8052 - val_sparse_categorical_accuracy: 0.7647
# Epoch 977/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2380 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.2381 - val_sparse_categorical_accuracy: 0.9748
# Epoch 978/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1623 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.2458 - val_sparse_categorical_accuracy: 0.9664
# Epoch 979/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3353 - sparse_categorical_accuracy: 0.9004 - val_loss: 0.2882 - val_sparse_categorical_accuracy: 0.9412
# Epoch 980/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1730 - sparse_categorical_accuracy: 0.9680 - val_loss: 0.2836 - val_sparse_categorical_accuracy: 0.9412
# Epoch 981/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1961 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.3144 - val_sparse_categorical_accuracy: 0.9328
# Epoch 982/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1814 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.3219 - val_sparse_categorical_accuracy: 0.9328
# Epoch 983/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2042 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.3722 - val_sparse_categorical_accuracy: 0.9076
# Epoch 984/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1813 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.2722 - val_sparse_categorical_accuracy: 0.9412
# Epoch 985/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2111 - sparse_categorical_accuracy: 0.9466 - val_loss: 0.2661 - val_sparse_categorical_accuracy: 0.9412
# Epoch 986/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1890 - sparse_categorical_accuracy: 0.9502 - val_loss: 0.3585 - val_sparse_categorical_accuracy: 0.8992
# Epoch 987/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1671 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.2531 - val_sparse_categorical_accuracy: 0.9496
# Epoch 988/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.3143 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.2865 - val_sparse_categorical_accuracy: 0.9244
# Epoch 989/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2226 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.2987 - val_sparse_categorical_accuracy: 0.9328
# Epoch 990/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2331 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.3540 - val_sparse_categorical_accuracy: 0.9160
# Epoch 991/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1892 - sparse_categorical_accuracy: 0.9466 - val_loss: 0.2819 - val_sparse_categorical_accuracy: 0.8992
# Epoch 992/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2306 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.2540 - val_sparse_categorical_accuracy: 0.9244
# Epoch 993/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1967 - sparse_categorical_accuracy: 0.9680 - val_loss: 0.2726 - val_sparse_categorical_accuracy: 0.9496
# Epoch 994/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.1818 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.2437 - val_sparse_categorical_accuracy: 0.9496
# Epoch 995/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2835 - sparse_categorical_accuracy: 0.9217 - val_loss: 0.5601 - val_sparse_categorical_accuracy: 0.8235
# Epoch 996/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.3296 - sparse_categorical_accuracy: 0.9075 - val_loss: 0.3184 - val_sparse_categorical_accuracy: 0.9496
# Epoch 997/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1842 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.2516 - val_sparse_categorical_accuracy: 0.9748
# Epoch 998/1000
# 141/141 [==============================] - 2s 14ms/step - loss: 0.2081 - sparse_categorical_accuracy: 0.9395 - val_loss: 0.3106 - val_sparse_categorical_accuracy: 0.8992
# Epoch 999/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.1897 - sparse_categorical_accuracy: 0.9537 - val_loss: 0.2821 - val_sparse_categorical_accuracy: 0.9328
# Epoch 1000/1000
# 141/141 [==============================] - 2s 15ms/step - loss: 0.2415 - sparse_categorical_accuracy: 0.9502 - val_loss: 0.4341 - val_sparse_categorical_accuracy: 0.8655
# Model: "augumentation_10CL"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 128, 128, 3)       0
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 8)       224
#
#  max_pooling2d_10 (MaxPoolin  (None, 64, 64, 8)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 8)         584
#
#  max_pooling2d_11 (MaxPoolin  (None, 32, 32, 8)        0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 16)        1168
#
#  max_pooling2d_12 (MaxPoolin  (None, 16, 16, 16)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 16)        2320
#
#  max_pooling2d_13 (MaxPoolin  (None, 8, 8, 16)         0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 16)          2320
#
#  max_pooling2d_14 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 16)          2320
#
#  max_pooling2d_15 (MaxPoolin  (None, 2, 2, 16)         0
#  g2D)
#  conv2d_16 (Conv2D)          (None, 2, 2, 16)          2320
#
#  max_pooling2d_16 (MaxPoolin  (None, 1, 1, 16)         0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 1, 1, 32)          4640
#
#  max_pooling2d_17 (MaxPoolin  (None, 1, 1, 32)         0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 1, 1, 64)          18496
#
#  max_pooling2d_18 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 1, 1, 64)          36928
#
#  max_pooling2d_19 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 256)               16640
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 64)                16448
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 104,733
# Trainable params: 104,733
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Carregando Modelo

# %%
#Carregando checkpoint
model_augumentation.load_weights('./checkpoints/checkpoint')

summary = model_augumentation.summary()
# Out:
# Model: "augumentation_10CL"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 128, 128, 3)       0
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 8)       224
#
#  max_pooling2d_10 (MaxPoolin  (None, 64, 64, 8)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 8)         584
#
#  max_pooling2d_11 (MaxPoolin  (None, 32, 32, 8)        0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 16)        1168
#
#  max_pooling2d_12 (MaxPoolin  (None, 16, 16, 16)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 16)        2320
#
#  max_pooling2d_13 (MaxPoolin  (None, 8, 8, 16)         0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 16)          2320
#
#  max_pooling2d_14 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 16)          2320
#
#  max_pooling2d_15 (MaxPoolin  (None, 2, 2, 16)         0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 2, 2, 16)          2320
#
#  max_pooling2d_16 (MaxPoolin  (None, 1, 1, 16)         0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 1, 1, 32)          4640
#
#  max_pooling2d_17 (MaxPoolin  (None, 1, 1, 32)         0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 1, 1, 64)          18496
#
#  max_pooling2d_18 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 1, 1, 64)          36928
#
#  max_pooling2d_19 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 256)               16640
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 64)                16448
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 104,733
# Trainable params: 104,733
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Resultados com Augumentation

# %%
import statistics 

acc = history_augumentation.history['sparse_categorical_accuracy'][1:1000]
val_acc = history_augumentation.history['val_sparse_categorical_accuracy'][1:1000]

loss = history_augumentation.history['loss'][1:1000]
val_loss = history_augumentation.history['val_loss'][1:1000]

epochs_range = range(1,1000)
print(epochs_range)

plt.figure(figsize=(40, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./statistics/training_x_val.png',  dpi = 300)
plt.show()
# Out:
# range(1, 1000)

# %% [markdown]
# ## Evaluate

# %%
print("Evaluate on test data")
results = model_augumentation.evaluate(x_val, y_val, batch_size=2)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2134 - sparse_categorical_accuracy: 0.9748
# test loss, test acc: [0.2134401500225067, 0.9747899174690247]

# %% [markdown]
# ## Matriz de Confusão

# %%
predictions = model_augumentation.predict(x_val)
pred_labels = []
for predict in predictions:
    pred_labels.append(np.argmax(predict))
confusion_matrix = tf.math.confusion_matrix(y_val, pred_labels)
print(confusion_matrix)
# Out:
# tf.Tensor(
# [[17  0  0  0  0]
#  [ 0 27  0  1  0]
#  [ 0  0 21  0  0]
#  [ 0  1  0 27  0]
#  [ 1  0  0  0 24]], shape=(5, 5), dtype=int32)

# %% [markdown]
# ## Heatmap

# %%
y_pred_classes = np.argmax(predictions, axis=1)

y_true = y_val
errors = (y_pred_classes - y_true != 0)

labels = ['1','2','3','4','5']

y_pred_classes_errors = y_pred_classes[errors]
y_pred_errors = predictions[errors]
y_true_errors = y_true[errors]
x_test_errors = []

cm = sklearn.metrics.confusion_matrix(y_true, y_pred_classes)
thresh = cm.max() / 2,

fig, ax = plt.subplots(figsize = (12, 12))
im, cbar = stats.heatmap(cm, labels, labels, ax = ax,
cmap = plt.cm.Blues, cbarlabel = 'count of predictions')

texts = stats.annotate_heatmap(im, data = cm, threshold = thresh)

fig.tight_layout()
plt.show()
fig.savefig('statistics/heatmap.png', dpi=72)

# %% [markdown]
# ## Classification report

# %%
target_names = ['class 1', 'class 2', 'class 3','class 4', 'class 5']
classification_report = sklearn.metrics.classification_report(pred_labels, y_val, target_names=target_names)

# %% [markdown]
# ## Salvando Relatórios

# %%
arq = open("./statistics/relatorio.txt", 'w')
arq.write(f"Modelo:Augumentation 10 Camadas de Convolução\n\nEvaluate:\n{results}\n\n Matriz de Confusão:\n{confusion_matrix}\n\nClassification Report:\n{classification_report}\n\n")
arq.close()
